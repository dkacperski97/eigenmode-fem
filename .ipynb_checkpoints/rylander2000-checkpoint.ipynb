# %% [markdown]
# ### Edge elements on triangles
# This is based on $2 \times 2$-element resonator example from "Computational Electromagnetics", 2000
# but solved with code from Davidson ("Computational Electromagnetics for RF and Microwave Engineering", 2011)

# %%
# helper functions
using LinearAlgebra
include("whitney.jl")
include("meshing.jl")
include("fem.jl")
include("distmesh-julia/test.jl")
nothing

# %%
# Parameters
ε0 = 1.
μ0 = 1.
εr = 1.
μr = 1.
σ  = 0.
ε  = ε0 * εr
μ  = μ0 * μr

a, b = 1.3, 0.9
n, m = 13, 9
nothing

# %%
# using PyPlot

# a, b = 1.3, 0.9
# n, m = 13, 9
# LOCALEDGENODES = [1 2; 1 3; 2 3]
# trimesh(a, b, n, m)
# triedgemake()

# figure(figsize=(5,1))
# triplot(NODE_COORD[:,1], NODE_COORD[:,2], triangles=(ELEMENTS .- 1)); # subtract 1 as we go into Python-world
# axis("equal");

# %%
# import Plots
# pv = [-0.4 -0.5;0.4 -0.2;0.4 -0.7;1.5 -0.4;0.9 0.1;
#       1.6 0.8;0.5 0.5;0.2 1;0.1 0.4;-0.7 0.7;-0.4 -0.5]
# fd = p -> dpolygon( p, pv )
# fh = p -> ones(size(p,1))
# h0=0.1
# bbox=[-1 -1;2 1]
# p_fix=pv
# e_fix=[]
# it_max=2000
# (p, t) = distmesh( fd, fh, h0, bbox, p_fix, e_fix, it_max )
# x = pv[:,1]
# y = pv[:,2]
# plotgrid( p, t )                                                        
# # # y = fd(x)
# Plots.plot!(x, y)
# # scatter!(p[:,1], p[:,2],markersize=1)
# # # scatter!(p[:,1], p[:,2])
# # # pv[:,1]

# %%
# using PyPlot

a, b = 1.3, 0.9

pv = [0 0; a 0; a b; 0 b; 0 0]
fd = p -> dpolygon( p, pv )
fh = p -> ones(size(p,1))
h0=0.15
bbox=[0 0;a b]
p_fix=pv
e_fix=[]
it_max=1000
(p, t) = distmesh( fd, fh, h0, bbox, p_fix, e_fix, it_max )
sort!(t, dims=2) # element nodes have to be sorted
x = pv[:,1]
y = pv[:,2]
plotgrid( p, t )                                                        
# # y = fd(x)
Plots.plot!(x, y)


# a, b = 1.3, 0.9
# n, m = 13, 9
# LOCALEDGENODES = [1 2; 1 3; 2 3]
# trimesh(a, b, n, m)
# triedgemake()

# figure(figsize=(5,1))
# triplot(NODE_COORD[:,1], NODE_COORD[:,2], triangles=(ELEMENTS .- 1)); # subtract 1 as we go into Python-world
# axis("equal");

# %%
epsilon = 0.001
# bottom_row_points
p[p[:, 1] .< epsilon, 1] .= 0
# top_row_points
p[p[:, 2] .> b - epsilon, 2] .= b
# left_column_points
p[p[:, 2] .< epsilon, 2] .= 0
# right_column_points
p[p[:, 1] .> a - epsilon, 1] .= a


plotgrid( p, t )                                                        
# # y = fd(x)
Plots.plot!(x, y)

# %%
# map distmesh results to correct format

NODE_COORD = p
ELEMENTS = t
NUM_NODES = size(NODE_COORD, 1)
NUM_ELEMS = size(ELEMENTS, 1)
LOCALEDGENODES = [1 2; 1 3; 2 3];
triedgemake()
# sets:
# EDGES
# NODE_EDGES
# ELEMENT_EDGES
# NUM_EDGES

# %%
dof = collect(1:NUM_EDGES)

Γ = dof_type(a, b)
dof_renumber!(dof, Γ);

# %%
S, T = assemble()

# %%
using PyPlot
figure(figsize=(5, 2))
subplot(1, 2, 1); spy(S); title("S"); xticks([]); yticks([]);
subplot(1, 2, 2); spy(T); title("T"); xticks([]); yticks([]);
tight_layout()
# Out:
# Figure(PyObject <Figure size 500x200 with 2 Axes>)

# %%
using PyPlot
# figure(figsize=(5, 2))
plot(1, 2, 1); spy(S); title("S"); xticks([]); yticks([]);
# subplot(1, 2, 2); spy(T); title("T"); xticks([]); yticks([]);
tight_layout()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
using LinearAlgebra

k², e = eigen(S, T)

speed_of_light = 299_792_458.
for n in 1:length(k²)
    wavenumber_squared = k²[n]
    if imag(wavenumber_squared) ≈ 0.0
        if real(wavenumber_squared) > 0.0
            frequency = sqrt(abs(wavenumber_squared)) / 2π * speed_of_light
            if 112e6 < frequency < 116e6
                println(n, ". ", 1e-6frequency, "MHz")
            end
        end
    end
end
# Out:
# 1. 2.1570346434573553e-6MHz
# 2. 55.252077123678156MHz
# 3. 94.0527701332468MHz
# 4. 162.14118813498462MHz
# 5. 182.46057920436817MHz
# 6. 242.59815151295547MHz
# 7. 272.26533184137384MHz
# 8. 369.86302025414545MHz
# 9. 404.9479971867907MHz
# 10. 431.25185286059246MHz
# 11. 457.12281274526634MHz
# 12. 520.5191164617861MHz
# 13. 569.012122507464MHz

# %%
n = 38
x = 0.1:0.15:1.2
y = 0.1:0.15:0.8
E = evaluate(WhitneyTriangleElement(), e[:, n], dof, x, y)
normE  = @. sqrt(E[:, :, 1]^2 + E[:, :, 2]^2)
xx = [x for _ in y, x in x]
yy = [y for y in y, _ in x]

figure(figsize=(5, 5))
contourf(xx', yy', normE, levels=20)
quiver(xx', yy', E[:, :, 1], E[:, :, 2])
xlim([-0.1, +1.3])
ylim([-0.1, +0.9])
 xticks([]); yticks([]);
# Out:
# Figure(PyObject <Figure size 500x500 with 1 Axes>)
